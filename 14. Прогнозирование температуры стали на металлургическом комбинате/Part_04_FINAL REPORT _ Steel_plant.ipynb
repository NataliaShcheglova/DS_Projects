# %% [markdown]
# ## <font color="	steelblue">ОТЧЕТ О ПРОЕКТЕ </font>
# # <font color="	steelblue">Прогнозирование температуры стали на металлургическом комбинате 🔮</font>

# %% [markdown]
# ![0001.jpg](attachment:0001.jpg)

# %% [markdown]
# *17 июня 2023 года*
#
# Данный отчет содержит информацию о выполненном проекте - математической модели для прогнозирования температуры стали, которая  позволит прогнозирует конечную температуру стали, что позволит сократить количество итераций нагрева стали, снизить потребление энергии и, следовательно, оптимизировать производственные расходы.
# __________________________________________________________________________________________________________________________
#
# # <font color="	steelblue">Содержание отчета</font>
#
# 1. [Понимание бизнеса](#понимание-бизнеса)
#     - [Ситуация](#ситуация)
#     - [Рекомендации](#рекомендации)
#     - [Область применения](#область-применения)
#     - [План работы](#план-работы)
#     - [Персонал команды](#персонал-команды)
#     - [Показатели](#показатели)
#
# 2. [Сбор и понимание данных](#сбор-и-понимание-данных)
#     - [Исходные данные](#исходные-данные)
#     - [Исследование данных](#исследование-данных)
#
# 3. [Предобработка данных](#предобработка-данных)
#
# 4. [Моделирование](#моделирование)
#     - [Подготовка тестовой и обучающей выборки](#подготовка-тестовой-и-обучающей-выборки)
#     - [Стандартизация числовых характеристик](#стандартизация-числовых-характеристик)
#     - [Обучение моделей](#обучение-моделей)
#     - [Оценка моделей](#оценка-моделей)
#     - [Тестирование лучшей модели](#тестирование-лучшей-модели)
#
# [Выводы](#выводы)
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# <a id='понимание-бизнеса'></a>
# # <font color="	steelblue">1. Понимание бизнеса</font>
#
# <font color="steelblue"><b>СИТУАЦИЯ | ОПРЕДЕЛЕНИЕ ЗАДАЧИ</b></font>
# <a id='ситуация'></a>
#
# - Специалисты «ЯП» выполнили исследовательский анализ процесса выплавки легированной стали в электродуговой печи металлургического комбинат ООО "Так закаляем сталь" с целью выявления путей повышения энергоэффективности предприятия с последующей выдачей рекомендаций.
#
# - Специалисты металлургического комбината ООО "Так закаляем сталь" заинтересованы в выявлении возможностей уменьшения потребления электроэнергии на этапе обработки стали, снижении производственных расходов, а также в комфортной и безопасной работе персонала.
#
#
# <font color="steelblue"><b>РЕКОМЕНДАЦИИ</b></font>
# <a id='рекомендации'></a>
#
# В числе первоочередных мер специалисты «ЯП» рекомендует  ООО "Так закаляем сталь"  следующие действия, направленные на повышение энергоэффективности:
# - Для оптимизации процесса выплавки стали применить разработанную в проекте модель, способную предсказывать температуру стали.
#
# Фактические данные, подтверждающие эффективность предложенных рекомендаций рассмотрены далее в текущем отчете.
#
#
# <font color="steelblue"><b>ОБЛАСТЬ ПРИМЕНЕНИЯ</b></font>
# <a id='область-применения'></a>
#
# Применение математической модели для прогнозирования температуры стали позволит сократить количество итераций нагрева стали, снизить потребление энергии и, следовательно, оптимизировать производственные расходы.
#
# Рекомендации «ЯП»  позволят добиться преимуществ следующих ключевых областях:
#
#
#
# |                             |                                                                                      |                                                                                 |
# |-----------------------------|--------------------------------------------------------------------------------------|---------------------------------------------------------------------------------|
# |<font color="royalblue"><b>⚙️ПРОИЗВОДИТЕЛЬНОСТЬ</b></font>          | Улучшение экономических и финансовых показателей                     | за счет снижения энергозатрат на этапе обработки стали                               |
# |<font color="tomato"><b>🦺 БЕЗОПАСНОСТЬ</b></font>                 | Снижение рисков, возникающих в результате прямого контакта персонала с оборудованием |  за счет воспроизведения экспериментов в цифровом виде и тестирования только лучших результатов на реальном производстве                                                                               |
# |<font color="darkolivegreen"><b>♻️ОКРУЖАЮЩАЯ СРЕДЫ</b></font>     | Снижение воздействия на окружающую среду                             | за счет сокращения количества итераций нагрева стали и уменьшения потребления электроэнергии |
#
#
# <font color="steelblue"><b>ПЛАН РАБОТЫ</b></font>
# <a id='план-работы'></a>
#
# Для достижения поставленной цели был разработан следующий план работы:
# 1.	Исследовательский анализ данных
# 2.	Предобработка данных
# 3.  Моделирование
# 3.	Вводы и рекомендации
#
# <font color="steelblue"><b>ПЕРСОНАЛ КОМАНДЫ</b></font>
# <a id='персонал-команды'></a>
#
# Проект вполняется одним специалистом по Data Science под руководством тим-лида.
#
# - Тим лид выполняет функцию руководителя проекта и осуществяет контакт с заказчиком и передачу ТЗ.
# - Специалистом по Data Science выполняет различные этапы по анализу и обработке данных, создает и сравинивает модели, тестирует и оценивает окончательную версию модели.
#
# <font color="steelblue"><b>ПОКАЗАТЕЛИ</b></font>
# <a id='показатели'></a>
#
# - Производительтность модели машинного обучения будет оцениваться на тестовом наборе данных, составляющем 25% от основного набора данных. Выболрка приедоставлена клиентом.
# - Точность измеряется и сообщается с помощью MAE. Значение МАЕ < 6.8 будет считаться приемлемым и подходящим для запуска в продакшн.
#
# ____________________________________________________________________________________________________________________________
#
# <a id='сбор-и-понимание-данных'></a>
# # <font color="	steelblue">2. Сбор и понимание данных</font>
#
# <a id='исходные-данные'></a>
# <font color="steelblue"><b>ИСХОДНЫЕ ДАННЫЕ</b></font>
#
# Для создания модели необходимо предоставлены данные, относящиеся к технологическому процессу производства стали. Эти данные включают информацию о различных параметрах, влияющих на нагрев стали, таких как время, мощность и температура, подача сыпучих и проволочных материалов и продувке газом.
#
# Для получения подробной информации о данных и сслок на датасеты, пожалуйста, ознакомьтесь с [Описанием данных](#описание_данных) в данной работе.
# Всего предоставлено 7 датасетов,  содержащих информацию за период с мая по сентябрь 2019 года (пять месяцев эксплуатации).
#
# <a id='исследование-данных'></a>
# <font color="steelblue"><b>ИССЛЕДОВАНИЕ ДАННЫХ</b></font>
#
# В ходе анализа проведены следующие действия:
# - изучена основная информация о датасетах (методами describe() и info()), типы данных, наличие и характер пропусков и выбросов (с помощью гистограмм и диаграммы размаха),
# - установлен и описаны взаимосвязи между датасетами и данными в них,
# - сформулированы выводы по проделанному анализу, список уточняющих вопросов заказчику и план работы.
#
# Расположение окончательного отчета об ознакомлении с данными и исследовательском анализе данных находятся здесь: [Выводы - исследовательский_анализ](#исследовательский_анализ)
#
# ___________________________________________________________________________________________________________________________
#
# <a id='предобработка-данных'></a>
# # <font color="	steelblue">3. Предобработка данных</font>
#
# **Перед проектированием обьекта были проведены следующие преобразования данных с целью разработки функциональных возможностей:**
#
# - Обработка пропущенных значений: пропуски в датасетах (в столбцах, содержащих информацию о подаче сыпучих и проволочных материалов (объем и время)) были заменены нулевыми значениями, поскольку отсутвие данных в столбцах является особенностью технологического процесса.
# - Удаление аномальных значений: На этапе предобработки были удалены аномальные значения из данных, такие как экстремально низкое (отрицательное) значение реактивной мощности и значения температуры ниже порогового значения, указанного заказчиком.
# - Сгенерированы дополнительные признаки: Начальная температура, Энергия, Время нагрева, количество газа в единицу времени и целевой признак (Конечная температура). Из талицы признаков после ее анализа были удалены столбцы с обьемом газа и обьединены wire_8 и bulk_9 с высокой корреляцией.
# - Создана таблица признаков, которая включает новые признаки. Данные обьединены по ключу key - номер партии.
#
# Более подробно ознакомиться с отчетом о предобработке данных и анализе таблицы признаков можно по ссылке [Выводы - Предобработка_данных](#Предобработка_данных)
# _____________________________________________________________________________________________________________________________
#
# <a id='моделирование'></a>
# # <font color="	steelblue">4. Моделирование</font>
#
# <a id='подготовка-тестовой-и-обучающей-выборки'></a>
# <font color="steelblue"><b>ПОДГОТОВКА ТЕСТОВОЙ И ОБУЧАЮЩЕЙ ВЫБОРКИ</b></font>
#
# Перед созданием моделей были выделены признаки и целевой признак из общей таблиц признаков, подготовленной на предудущем этапе. Затем была подготовлена обучающая и тестовая выборки в соотношении 75:25.
#
# <a id='стандартизация-числовых-характеристик'></a>
# <font color="steelblue"><b>СТАНДАРТИЗАЦИЯ ЧИСЛОВЫХ ХАРАКТЕРИСТИК</b></font>
#
# Числовые зарактеристики были стандартизированы для обучения одной модели - линейной регрессии. Для стандартизации данных использовалась стандартный класс [StandardScaler() из библиотеки sklearn.preprocessing](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html). Преобразование выолняется на первом шаге пайплайна с применением [Pipeline из библиотеки sklearn.pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html)
#
# <a id='обучение-моделей'></a>
# <font color="steelblue"><b>ОБУЧЕНИЕ МОДЕЛЕЙ</b></font>
#
# В ходе работы созданы три модели:
# - одну модель линейной регрессии [LinearRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html) и подбором параметров с пятнадцатикратной кросс-валидацией.
# - две бустинговые модели [СatBoostRegressor](https://catboost.ai/en/docs/concepts/python-reference_catboostregressor) и [LGBMRegressor](https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMRegressor.html) с пятикратной перекрестной проверкой и подбором гиперпараметров с испьзованием [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html).
#
# <a id='оценка-моделей'></a>
# <font color="steelblue"><b>ОЦЕНКА МОДЕЛЕЙ</b></font>
#
# После обучения моделей производена их оценка с использованием соответствующих метрик. В данном случае, основной метрикой была выбрана Mean Absolute Error (MAE). Модели оценивались на обучающей выборке с применением кросс-валидации и с испьзованием GridSearchCV, и результаты MAE сравнивались с пороговым значением MAE = 6.8.
#
# В результате оценки было выявлено, что успешно прошли пороговое значение MAE = 6.8 на обучающей выборке:
# - Модель CatBoostRegressor с наилучшими параметрами {'depth': 5, 'learning_rate': 0.05, 'n_estimators': 310} показала наименьшее значение MAE = 6.02.
# - Модель LinearRegression показала наихудший результат MAE = 6.25, но имеет преимущество в скорости обучения.
# - Модель LGBMRegressor с параметрами {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 45} показала средний результат MAE = 6.07.
#
# Для проверки адекватности моделей была использована дамми модель, которая выдала значительно большее значение MAE = 8.61. Таким образом, лучшая модель CatBoostRegressor прошла проверку на адекватность.
#
# <a id='тестирование-лучшей-модели'></a>
# <font color="steelblue"><b>ТЕСТИРОВАНИЕ ЛУЧШЕЙ МОДЕЛИ</b></font>
#
# В результате проверки на тестовой выборке модель CatBoostRegressor, настроенная с использованием следующих параметров: глубина деревьев (depth) = 5, скорость обучения (learning_rate) = 0.05 и количество деревьев (n_estimators) = 310, продемонстрировала значение средней абсолютной ошибки (MAE) равное 6.42, что оказалось ниже установленного порогового значения MAE = 6.8.
#
# Графики предсказанных и фактических значений и График остатков (ниже) для тестовых данных показан ниже для лучшей модели CatBoostRegressor:

# %% [markdown]
# ![graphs.JPG](attachment:graphs.JPG)

# %% [markdown]
# Важность признаков лучшей модели CatBoostRegressor изображена ниже:

# %% [markdown]
# ![graph2.JPG](attachment:graph2.JPG)

# %% [markdown]
# <a id='выводы'></a>
# # <font color="	steelblue">Выводы</font>
#
# В числе первоочередных мер «ЯП» рекомендует OOО «Так закаляем сталь» следующие действия, направленные на оптимизацию процесса выплавки стали и сокращение затрат на снижение потребления энергии:
#
# - **Применение модели машинного обучения CatBoostRegressor**, настроенной с использованием следующих параметров: глубина деревьев (depth) = 5, скорость обучения (learning_rate) = 0.05 и количество деревьев (n_estimators) = 310, которая продемонстрировала **значение средней абсолютной ошибки (MAE) равное 6.42 на тестовой выборке**, что оказалось ниже установленного порогового значения MAE = 6.8.
#
# Это позволит воспроизводить эксперименты в цифровом виде и тестировать только лучшие результаты на реальном производсве. Также можно выявить параметры, оказывают наибольшее влияние на нагрев стали. Модель должна предсказывать конечную температуру стали. Данная раота позволит сократить количество итерций нагрева стали и, ледовательно, снизить потребление энергии.
#
# **В качестве первоочередных шагов для получения представленной в этом отчете выгоды мы рекомендуем следующие шаги:**
# 1. Назначить совещание по согласованию деталей развертывания представленной  в отчете модели,
# 3. Изучить параметры, оказывающие наибольшее влияние на нагрев стали и пути их корректировки,
# 2. Назначить сроки выполнения рекомендаций.
#
# Благодарим специалистов OOО «Так закаляем сталь» за рассмотрение данного отчета и содействие в проведении совместной работы.
